# %%
import warnings 
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
import torch 
import torch.nn as nn

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
plt.style.use(style='ggplot')
# %matplotlib inline

# %%
train = pd.read_csv('train-data.csv')
test = pd.read_csv('test-data.csv')
print(train.shape)
print(train.info())
print(test.shape)
print(test.info())
# Out:
# (6019, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB
# None
# (1234, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1234 non-null   int64
#  1   Name               1234 non-null   object
#  2   Location           1234 non-null   object
#  3   Year               1234 non-null   int64
#  4   Kilometers_Driven  1234 non-null   int64
#  5   Fuel_Type          1234 non-null   object
#  6   Transmission       1234 non-null   object
#  7   Owner_Type         1234 non-null   object
#  8   Mileage            1234 non-null   object
#  9   Engine             1224 non-null   object
#  10  Power              1224 non-null   object
#  11  Seats              1223 non-null   float64
#  12  New_Price          182 non-null    object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 125.5+ KB
# None

# %%
train.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %%
test.head()
# Out:
#    Unnamed: 0                                       Name    Location  Year  \
# 0           0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1           1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2           2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3           3                       Toyota Etios Liva GD   Hyderabad  2012
# 4           4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price
# 0   58.2 bhp    4.0         NaN
# 1   47.3 bhp    5.0         NaN
# 2  147.8 bhp    7.0  25.27 Lakh
# 3   null bhp    5.0         NaN
# 4  82.85 bhp    5.0         NaN

# %%
print(train.shape, test.shape)
train.drop('New_Price', axis=1, inplace=True)
test.drop('New_Price', axis=1, inplace=True)
print(train.shape, test.shape)
# Out:
# (6019, 14) (1234, 13)
# (6019, 13) (1234, 12)

# %% [markdown]
# # Data Cleaning and Feature Engineering

# %%
print(train.isnull().sum())
print("------------------------")
print(test.isnull().sum())
# Out:
# Unnamed: 0            0
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64
# ------------------------
# Unnamed: 0            0
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               0
# Engine               10
# Power                10
# Seats                11
# dtype: int64

# %% [markdown]
# ## Unnamed

# %%
print(train['Unnamed: 0'].value_counts())
# Out:
# 2047    1
# 2720    1
# 2708    1
# 661     1
# 4759    1
#        ..
# 5436    1
# 1342    1
# 3391    1
# 5440    1
# 0       1
# Name: Unnamed: 0, Length: 6019, dtype: int64

# %%
unnamed_train = list(train['Unnamed: 0'].unique())
unnamed_test = list(test['Unnamed: 0'].unique())
for i in unnamed_test:
    if i not in unnamed_train:
        print(i)

# %% [markdown]
# ## Name

# %%
print(train['Name'].value_counts())
print(train['Unnamed: 0'].value_counts())
# Out:
# Mahindra XUV500 W8 2WD                          49
# Maruti Swift VDI                                45
# Maruti Swift Dzire VDI                          34
# Honda City 1.5 S MT                             34
# Maruti Swift VDI BSIV                           31
#                                                 ..
# Hyundai i20 Era 1.4 CRDi                         1
# Audi Q7 4.2 FSI quattro                          1
# Toyota Qualis FS B2                              1
# Chevrolet Tavera LS B3 10 Seats BSIII            1
# Volkswagen Jetta 2013-2015 2.0L TDI Highline     1
# Name: Name, Length: 1876, dtype: int64
# 2047    1
# 2720    1
# 2708    1
# 661     1
# 4759    1
#        ..
# 5436    1
# 1342    1
# 3391    1
# 5440    1
# 0       1
# Name: Unnamed: 0, Length: 6019, dtype: int64

# %%
print(test['Name'].value_counts())
# Out:
# Maruti Alto LXi                     9
# Volkswagen Polo 1.2 MPI Highline    8
# Honda City 1.5 V MT                 8
# Maruti Swift Dzire VDI              8
# Maruti Alto 800 2016-2019 LXI       7
#                                    ..
# Mercedes-Benz SLC 43 AMG            1
# Chevrolet Sail Hatchback LS ABS     1
# Chevrolet Spark 1.0 PS              1
# Maruti Alto XCITE                   1
# Skoda Rapid 1.6 MPI Ambition        1
# Name: Name, Length: 768, dtype: int64

# %%
car_names_train = list(train['Name'].unique())
car_names_test = list(test['Name'].unique())
for i in car_names_test:
    if i not in car_names_train:
        print(i)
# Out:
# Toyota Innova Crysta Touring Sport 2.4 MT
# Maruti Swift AMT ZXI
# Skoda Laura 1.8 TSI Ambition
# Honda Civic 2010-2013 1.8 S MT Inspire
# Toyota Etios Liva 1.4 VXD
# Maruti Celerio X VXI Option
# Chevrolet Sail Hatchback 1.2
# Mahindra Scorpio VLX Special Edition BS-IV
# Tata Tiago AMT 1.2 Revotron XTA
# Maruti Ciaz VXi
# Nissan Teana XL
# Tata Manza Club Class Safire90 LX
# Ford Fiesta Classic 1.6 SXI Duratec
# Mercedes-Benz B Class B180 Sports
# Nissan Micra XL CVT
# Tata Indica V2 DiCOR DLG BS-III
# Tata Indica Vista Quadrajet LX
# Audi Q3 30 TDI S Edition
# Honda BRV i-DTEC V MT
# BMW 3 Series GT 320d Sport Line
# Toyota Etios Liva VD
# Datsun GO T Petrol
# Maruti A-Star Zxi
# Mahindra KUV 100 mFALCON G80 K4 5str
# Ford Fiesta 1.4 SXI Duratorq
# Fiat Avventura FIRE Dynamic
# Honda CR-V Diesel
# Mahindra Xylo E9
# Hyundai Creta 1.6 SX Automatic
# Honda Mobilio V i VTEC
# Tata Indica Vista Aqua TDI BSIII
# Skoda Laura 1.9 TDI MT Elegance
# Honda City ZX VTEC Plus
# BMW 7 Series 730Ld DPE Signature
# Hindustan Motors Contessa 2.0 DSL
# Fiat Linea Dynamic
# Tata Sumo EX 10/7 Str BSII
# Fiat Grande Punto 1.2 Emotion
# Toyota Etios Cross 1.2L G
# Mahindra Thar 4X4
# Hyundai i20 Active SX Diesel
# Honda BR-V i-DTEC S MT
# Toyota Camry MT with Moonroof
# Mahindra Verito Vibe 1.5 dCi D6
# Volkswagen Jetta 2007-2011 1.6 Trendline
# Mahindra KUV 100 mFALCON D75 K2
# Bentley Flying Spur W12
# Tata Tigor 1.2 Revotron XZ Option
# Honda Accord 2001-2003 2.3 VTI L MT
# Land Rover Freelander 2 S Business Edition
# Ford Endeavour 3.0L AT 4x2
# Hyundai Santro Xing GLS CNG
# Toyota Land Cruiser Prado VX L
# Hyundai Tucson 2.0 e-VGT 4WD AT GLS
# Toyota Innova 2.5 GX 8 STR
# Maruti Wagon R VXI AMT Opt
# Skoda Laura L and K MT
# Land Rover Range Rover HSE
# Volkswagen Polo ALLSTAR 1.2 MPI
# Land Rover Discovery 4 SDV6 SE
# Honda City i DTec VX Option BL
# Hyundai Santro LS zipDrive Euro I
# Mitsubishi Pajero Sport 4X2 AT
# Hyundai Creta 1.6 SX Diesel
# Isuzu MU 7 4x2 HIPACK
# Hyundai Elantra GT
# Mercedes-Benz B Class B180 Sport
# Mahindra Bolero SLX
# Hyundai Xcent 1.2 CRDi SX
# BMW 5 Series 530i Sport Line
# Honda Jazz VX CVT
# Tata Indica Vista Aqua 1.2 Safire
# Toyota Etios Liva Diesel TRD Sportivo
# Skoda Rapid Ultima 1.6 TDI Ambition Plus
# Maruti SX4 ZXI AT
# Hyundai i20 new Sportz AT 1.4
# Mahindra Scorpio SLX 2.6 Turbo 8 Str
# BMW X3 2.5si
# Hyundai EON 1.0 Kappa Magna Plus
# Chevrolet Enjoy 1.3 TCDi LTZ 7
# Hyundai Verna 1.4 CX
# Mahindra KUV 100 D75 K8 5Str
# Hyundai EON 1.0 Era Plus
# Toyota Innova 2.0 V
# Mahindra Xylo H9
# Mahindra TUV 300 P4
# Maruti Ritz VDi ABS
# Volvo S60 D5 Kinetic
# Chevrolet Enjoy TCDi LS 7 Seater
# Mahindra Scorpio S10 8 Seater
# Renault Pulse RxZ
# Honda WRV i-DTEC VX
# Hyundai Accent GLX
# Mahindra KUV 100 G80 K4 Plus 5Str
# Tata Indica Vista Terra 1.2 Safire BS IV
# Volkswagen Vento 1.5 TDI Highline Plus
# Volkswagen CrossPolo 1.2 TDI
# Ford Ikon 1.4 ZXi
# Hyundai Verna Transform SX VGT CRDi BS III
# Volkswagen Vento 1.5 TDI Highline Plus AT
# Maruti 800 DX
# Maruti Ertiga VXI Petrol
# Fiat Avventura Urban Cross 1.3 Multijet Emotion
# Skoda Octavia 2.0 TDI MT Style
# Renault Duster 85PS Diesel RxZ
# Jaguar XF 2.0 Petrol Portfolio
# Honda Civic 2010-2013 1.8 V AT
# Hyundai Elantra SX AT
# Nissan 370Z AT
# Ford Classic 1.4 Duratorq CLXI
# Renault Koleos 4X2 MT
# Honda Amaze E i-DTEC
# Maruti Ciaz VDi Option SHVS
# Tata Indica Vista Terra Quadrajet 1.3L BS IV
# Mercedes-Benz GLA Class 220 d 4MATIC
# Mahindra Bolero Power Plus ZLX
# Fiat Linea Classic 1.3 Multijet
# Mahindra Scorpio VLS 2.2 mHawk
# Ford Freestyle Titanium Plus Diesel
# Maruti Swift VVT ZXI
# Fiat Punto EVO 1.3 Emotion
# Fiat Abarth 595 Competizione
# Hyundai Accent Executive LPG
# Honda BR-V i-VTEC VX MT
# Volkswagen Vento 1.6 Trendline
# Maruti Versa DX2
# Hyundai Sonata Embera 2.4L MT
# Honda Amaze VX CVT i-VTEC
# Honda Jazz 2020 Petrol
# Hyundai i20 1.4 Asta AT (O) with Sunroof
# Renault Lodgy 110PS RxL
# Mercedes-Benz E-Class 250 D W 124
# Toyota Innova 2.5 LE 2014 Diesel 8 Seater
# Mercedes-Benz E-Class E240 V6 AT
# Nissan Terrano XE 85 PS
# Mahindra TUV 300 2015-2019 T8 AMT
# Hyundai i20 2015-2017 1.4 CRDi Sportz
# Hyundai Creta 1.6 VTVT Base
# Maruti Ignis 1.2 AMT Delta
# Ford Fiesta Classic 1.6 Duratec LXI
# Toyota Corolla Altis GL
# OpelCorsa 1.4Gsi
# Volkswagen Vento 1.2 TSI Comfortline AT
# Hyundai Santro Xing XG AT eRLX Euro III
# Mahindra KUV 100 mFALCON D75 K6 5str AW
# Mahindra Scorpio VLX 2WD BSIII
# Chevrolet Enjoy Petrol LTZ 7 Seater
# Hyundai i20 2015-2017 Magna Optional 1.4 CRDi
# Mercedes-Benz CLA 45 AMG
# Audi Q5 2008-2012 3.0 TDI Quattro
# Chevrolet Spark 1.0 PS
# Chevrolet Enjoy 1.4 LTZ 8
# Maruti Vitara Brezza ZDi AMT
# Mercedes-Benz A Class Edition 1
# BMW 7 Series 740i Sedan
# Mercedes-Benz S Class 2005 2013 320 L
# Maruti Alto XCITE
# Land Rover Discovery 4 TDV6 Auto Diesel
# Hyundai Verna Transform VTVT with Audio
# Maruti Vitara Brezza ZDi Plus AMT
# Skoda Superb Petrol Ambition
# Tata Tiago 1.05 Revotorq XT Option
# Ford EcoSport 1.5 Petrol Ambiente
# Jeep Compass 1.4 Sport
# Hyundai Elite i20 Magna Plus

# %% [markdown]
# We can not handle all of these values, we have to drop the name column

# %%
print(train.shape, test.shape)
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)
print(train.shape, test.shape)
# Out:
# (6019, 13) (1234, 12)
# (6019, 12) (1234, 11)

# %% [markdown]
# ## Location

# %%
train['Location'][:20]
# Out:
# 0         Mumbai
# 1           Pune
# 2        Chennai
# 3        Chennai
# 4     Coimbatore
# 5      Hyderabad
# 6         Jaipur
# 7         Mumbai
# 8           Pune
# 9        Chennai
# 10         Kochi
# 11       Kolkata
# 12        Jaipur
# 13         Delhi
# 14          Pune
# 15         Delhi
# 16         Kochi
# 17        Jaipur
# 18         Kochi
# 19     Bangalore
# Name: Location, dtype: object

# %%
train['Location'].value_counts()
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %%
test['Location'].value_counts()
# Out:
# Mumbai        159
# Pune          143
# Coimbatore    136
# Hyderabad     134
# Kochi         121
# Kolkata       119
# Delhi         106
# Chennai        97
# Jaipur         86
# Bangalore      82
# Ahmedabad      51
# Name: Location, dtype: int64

# %% [markdown]
# ## Kilometers_Driven

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(train['Kilometers_Driven'])
plt.show()

# %%
temp2 = test[test['Kilometers_Driven'] > 400000]
temp2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats]
# Index: []

# %%
print(train.shape)
temp = train[train['Kilometers_Driven'] > 400000].index
train.drop(temp, axis=0, inplace=True)
print(train.shape)
# Out:
# (6019, 12)
# (6012, 12)

# %% [markdown]
# ## Fuel Type

# %%
train['Fuel_Type'][:20]
# Out:
# 0        CNG
# 1     Diesel
# 2     Petrol
# 3     Diesel
# 4     Diesel
# 5        LPG
# 6     Diesel
# 7     Diesel
# 8     Diesel
# 9     Diesel
# 10    Petrol
# 11    Petrol
# 12    Diesel
# 13    Diesel
# 14    Diesel
# 15    Diesel
# 16    Diesel
# 17    Diesel
# 18    Diesel
# 19    Diesel
# Name: Fuel_Type, dtype: object

# %%
train['Fuel_Type'].value_counts()
# Out:
# Diesel      3201
# Petrol      2743
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
test['Fuel_Type'].value_counts()
# Out:
# Diesel    647
# Petrol    579
# CNG         6
# LPG         2
# Name: Fuel_Type, dtype: int64

# %% [markdown]
# ## Transmission

# %%
train['Transmission'][:20]
# Out:
# 0        Manual
# 1        Manual
# 2        Manual
# 3        Manual
# 4     Automatic
# 5        Manual
# 6        Manual
# 7     Automatic
# 8        Manual
# 9        Manual
# 10       Manual
# 11    Automatic
# 12       Manual
# 13    Automatic
# 14    Automatic
# 15       Manual
# 16       Manual
# 17       Manual
# 18       Manual
# 19    Automatic
# Name: Transmission, dtype: object

# %%
train['Transmission'].value_counts()
# Out:
# Manual       4295
# Automatic    1717
# Name: Transmission, dtype: int64

# %%
test['Transmission'].value_counts()
# Out:
# Manual       905
# Automatic    329
# Name: Transmission, dtype: int64

# %% [markdown]
# ## Owner_Type

# %%
train['Owner_Type'][:20]
# Out:
# 0      First
# 1      First
# 2      First
# 3      First
# 4     Second
# 5      First
# 6      First
# 7      First
# 8      First
# 9     Second
# 10     First
# 11     First
# 12     First
# 13     First
# 14    Second
# 15     First
# 16     First
# 17     First
# 18     First
# 19     First
# Name: Owner_Type, dtype: object

# %%
train['Owner_Type'].value_counts()
# Out:
# First             4922
# Second             968
# Third              113
# Fourth & Above       9
# Name: Owner_Type, dtype: int64

# %%
test['Owner_Type'].value_counts()
# Out:
# First             1023
# Second             184
# Third               24
# Fourth & Above       3
# Name: Owner_Type, dtype: int64

# %% [markdown]
# ## Mileage

# %%
train['Mileage'][:20]
# Out:
# 0     26.6 km/kg
# 1     19.67 kmpl
# 2      18.2 kmpl
# 3     20.77 kmpl
# 4      15.2 kmpl
# 5     21.1 km/kg
# 6     23.08 kmpl
# 7     11.36 kmpl
# 8     20.54 kmpl
# 9      22.3 kmpl
# 10    21.56 kmpl
# 11     16.8 kmpl
# 12     25.2 kmpl
# 13     12.7 kmpl
# 14      0.0 kmpl
# 15     13.5 kmpl
# 16     25.8 kmpl
# 17     28.4 kmpl
# 18    20.45 kmpl
# 19    14.84 kmpl
# Name: Mileage, dtype: object

# %% [markdown]
# - km/kg: Kilometers per Kilogram
# - kmpl: Kilometers per Litre

# %%
train['Mileage'].value_counts(dropna=False)
# Out:
# 18.9 kmpl     172
# 17.0 kmpl     172
# 18.6 kmpl     119
# 20.36 kmpl     87
# 21.1 kmpl      86
#              ...
# 18.69 kmpl      1
# 21.1 km/kg      1
# 26.8 kmpl       1
# 12.98 kmpl      1
# 15.42 kmpl      1
# Name: Mileage, Length: 443, dtype: int64

# %%
# Null Values
train['Mileage'] = train['Mileage'].fillna('17.0 kmpl')

# %% [markdown]
# We can make 2 new columns, one for the value and one for the measurement to handle the mile age column, then we drop it.

# %%
train['Mileage'][0].split()[0], train['Mileage'][0].split()[1]
# Out:
# ('26.6', 'km/kg')

# %%
mile_age_val = pd.DataFrame(columns=['Mileage_value'])
mile_age_measure = pd.DataFrame(columns=['Mileage_measure'])
train = pd.concat([train, mile_age_val, mile_age_measure], axis=1)
test = pd.concat([test, mile_age_val, mile_age_measure], axis=1)

for i in train.index:
    value = train['Mileage'][i].split()[0]
    measure = train['Mileage'][i].split()[1]
    train['Mileage_value'][i] = value
    train['Mileage_measure'][i] = measure
    
for i in test.index:
    value = test['Mileage'][i].split()[0]
    measure = test['Mileage'][i].split()[1]
    test['Mileage_value'][i] = value
    test['Mileage_measure'][i] = measure
    
train.drop('Mileage', axis=1, inplace=True)
test.drop('Mileage', axis=1, inplace=True)

# %% [markdown]
# ## Engine

# %%
train['Engine'][:20]
# Out:
# 0      998 CC
# 1     1582 CC
# 2     1199 CC
# 3     1248 CC
# 4     1968 CC
# 5      814 CC
# 6     1461 CC
# 7     2755 CC
# 8     1598 CC
# 9     1248 CC
# 10    1462 CC
# 11    1497 CC
# 12    1248 CC
# 13    2179 CC
# 14    2179 CC
# 15    2477 CC
# 16    1498 CC
# 17    1248 CC
# 18    1461 CC
# 19    2143 CC
# Name: Engine, dtype: object

# %%
train['Engine'].value_counts()
# Out:
# 1197 CC    604
# 1248 CC    512
# 1498 CC    304
# 998 CC     259
# 2179 CC    240
#           ...
# 2925 CC      1
# 1489 CC      1
# 2720 CC      1
# 2999 CC      1
# 970 CC       1
# Name: Engine, Length: 146, dtype: int64

# %%
test['Engine'].value_counts()
# Out:
# 1197 CC    126
# 1248 CC     98
# 1498 CC     66
# 1198 CC     54
# 998 CC      50
#           ...
# 1590 CC      1
# 2198 CC      1
# 2446 CC      1
# 793 CC       1
# 1950 CC      1
# Name: Engine, Length: 104, dtype: int64

# %%
# Null Values
train['Engine'] = train['Engine'].fillna('1197 CC')
test['Engine'] = test['Engine'].fillna('1197 CC')

# %% [markdown]
# We are gonna do the same we did with Mileage

# %%
train['Engine'][0].split()[0], train['Engine'][0].split()[1]
# Out:
# ('998', 'CC')

# %%
engine_val = pd.DataFrame(columns=['Engine_value'])
engine_measure = pd.DataFrame(columns=['Engine_measure'])
train = pd.concat([train, engine_val, engine_measure], axis=1)
test = pd.concat([test, engine_val, engine_measure], axis=1)

for i in train.index:
    value = train['Engine'][i].split()[0]
    measure = train['Engine'][i].split()[1]
    train['Engine_value'][i] = value
    train['Engine_measure'][i] = measure
        
for i in test.index:
    value = test['Engine'][i].split()[0]
    measure = test['Engine'][i].split()[1]
    test['Engine_value'][i] = value
    test['Engine_measure'][i] = measure
    
train.drop('Engine', axis=1, inplace=True)
test.drop('Engine', axis=1, inplace=True)

# %%
train['Engine_measure'].value_counts()
# Out:
# CC    6012
# Name: Engine_measure, dtype: int64

# %%
train.drop('Engine_measure', axis=1, inplace=True)
test.drop('Engine_measure', axis=1, inplace=True)

# %%
train.shape, test.shape
# Out:
# ((6012, 13), (1234, 12))

# %% [markdown]
# ## Power

# %%
train['Power'][:20]
# Out:
# 0      58.16 bhp
# 1      126.2 bhp
# 2       88.7 bhp
# 3      88.76 bhp
# 4      140.8 bhp
# 5       55.2 bhp
# 6       63.1 bhp
# 7      171.5 bhp
# 8      103.6 bhp
# 9         74 bhp
# 10    103.25 bhp
# 11     116.3 bhp
# 12        74 bhp
# 13     187.7 bhp
# 14       115 bhp
# 15    175.56 bhp
# 16      98.6 bhp
# 17        74 bhp
# 18      83.8 bhp
# 19    167.62 bhp
# Name: Power, dtype: object

# %%
train['Power'].value_counts()
# Out:
# 74 bhp       235
# 98.6 bhp     131
# 73.9 bhp     125
# 140 bhp      123
# 78.9 bhp     110
#             ...
# 261 bhp        1
# 321 bhp        1
# 500 bhp        1
# 231.1 bhp      1
# 503 bhp        1
# Name: Power, Length: 372, dtype: int64

# %%
test['Power'].value_counts()
# Out:
# 74 bhp        45
# 98.6 bhp      35
# 73.9 bhp      27
# 82 bhp        23
# 86.8 bhp      22
#               ..
# 134 bhp        1
# 241.6 bhp      1
# 170.30 bhp     1
# 203.2 bhp      1
# 82.5 bhp       1
# Name: Power, Length: 249, dtype: int64

# %%
train['Power'].unique()
# Out:
# array(['58.16 bhp', '126.2 bhp', '88.7 bhp', '88.76 bhp', '140.8 bhp',
#        '55.2 bhp', '63.1 bhp', '171.5 bhp', '103.6 bhp', '74 bhp',
#        '103.25 bhp', '116.3 bhp', '187.7 bhp', '115 bhp', '175.56 bhp',
#        '98.6 bhp', '83.8 bhp', '167.62 bhp', '190 bhp', '88.5 bhp',
#        '177.01 bhp', '80 bhp', '67.1 bhp', '102 bhp', '108.45 bhp',
#        '138.1 bhp', '184 bhp', '179.5 bhp', '103.5 bhp', '64 bhp',
#        '82 bhp', '254.8 bhp', '73.9 bhp', '46.3 bhp', '37.5 bhp',
#        '77 bhp', '82.9 bhp', '149.92 bhp', '138.03 bhp', '112.2 bhp',
#        '163.7 bhp', '71 bhp', '105 bhp', '174.33 bhp', '75 bhp',
#        '103.2 bhp', '53.3 bhp', '78.9 bhp', '147.6 bhp', '147.8 bhp',
#        '68 bhp', '186 bhp', '170 bhp', '69 bhp', '140 bhp', '78 bhp',
#        '194 bhp', '500 bhp', '108.5 bhp', '86.8 bhp', '187.74 bhp',
#        'null bhp', '132 bhp', '86.7 bhp', '73.94 bhp', '117.3 bhp',
#        '218 bhp', '168.5 bhp', '89.84 bhp', '110 bhp', '90 bhp',
#        '82.85 bhp', '67 bhp', '241.4 bhp', '35 bhp', '270.9 bhp',
#        '126.32 bhp', '73 bhp', '130 bhp', '100.6 bhp', '150 bhp',
#        '75.94 bhp', '215 bhp', '107.3 bhp', '37.48 bhp', '120 bhp',
#        '178 bhp', '152 bhp', '91.1 bhp', '85.80 bhp', '362.07 bhp',
#        '121.3 bhp', '143 bhp', '81.80 bhp', '171 bhp', '76.8 bhp',
#        '103.52 bhp', '444 bhp', '362.9 bhp', '67.06 bhp', '120.7 bhp',
#        '258 bhp', '81.86 bhp', '112 bhp', '88.73 bhp', '57.6 bhp',
#        '157.75 bhp', '102.5 bhp', '201.1 bhp', '83.1 bhp', '68.05 bhp',
#        '88.50 bhp', nan, '106 bhp', '100 bhp', '81.83 bhp', '85 bhp',
#        '64.1 bhp', '177.5 bhp', '246.7 bhp', '177.46 bhp', '65 bhp',
#        '67.04 bhp', '189.08 bhp', '99 bhp', '53.5 bhp', '194.3 bhp',
#        '70 bhp', '183 bhp', '254.79 bhp', '66.1 bhp', '76 bhp', '60 bhp',
#        '123.24 bhp', '47.3 bhp', '118 bhp', '88.8 bhp', '177 bhp',
#        '136 bhp', '201.15 bhp', '93.7 bhp', '177.6 bhp', '313 bhp',
#        '245 bhp', '125 bhp', '227 bhp', '62 bhp', '141.1 bhp',
#        '83.14 bhp', '192 bhp', '67.05 bhp', '47 bhp', '235 bhp', '37 bhp',
#        '87.2 bhp', '203 bhp', '204 bhp', '246.74 bhp', '122 bhp',
#        '282 bhp', '181 bhp', '224 bhp', '94 bhp', '367 bhp', '98.79 bhp',
#        '62.1 bhp', '174.3 bhp', '114 bhp', '335.2 bhp', '169 bhp',
#        '191.34 bhp', '108.49 bhp', '138.02 bhp', '156 bhp', '187.4 bhp',
#        '66 bhp', '103.3 bhp', '164.7 bhp', '79.4 bhp', '198.5 bhp',
#        '154 bhp', '73.8 bhp', '181.43 bhp', '85.8 bhp', '207.8 bhp',
#        '108.4 bhp', '88 bhp', '63 bhp', '82.5 bhp', '364.9 bhp',
#        '107.2 bhp', '141 bhp', '113.98 bhp', '126.3 bhp', '185 bhp',
#        '237.4 bhp', '99.6 bhp', '66.7 bhp', '160 bhp', '306 bhp',
#        '98.59 bhp', '92.7 bhp', '147.51 bhp', '197.2 bhp', '167.6 bhp',
#        '165 bhp', '110.4 bhp', '73.97 bhp', '147.9 bhp', '116.6 bhp',
#        '148 bhp', '34.2 bhp', '155 bhp', '197 bhp', '108.62 bhp',
#        '118.3 bhp', '38.4 bhp', '241.38 bhp', '153.86 bhp', '163.5 bhp',
#        '226.6 bhp', '84.8 bhp', '53.64 bhp', '158.2 bhp', '69.01 bhp',
#        '181.03 bhp', '58.2 bhp', '104.68 bhp', '126.24 bhp', '73.75 bhp',
#        '158 bhp', '130.2 bhp', '57.5 bhp', '97.7 bhp', '121.4 bhp',
#        '98.96 bhp', '174.5 bhp', '308 bhp', '121.36 bhp', '138 bhp',
#        '265 bhp', '84 bhp', '321 bhp', '91.72 bhp', '65.3 bhp',
#        '88.2 bhp', '93 bhp', '35.5 bhp', '86.79 bhp', '157.7 bhp',
#        '40.3 bhp', '91.7 bhp', '180 bhp', '114.4 bhp', '158.8 bhp',
#        '157.8 bhp', '123.7 bhp', '56.3 bhp', '189 bhp', '104 bhp',
#        '210 bhp', '270.88 bhp', '142 bhp', '255 bhp', '236 bhp',
#        '167.7 bhp', '148.31 bhp', '80.46 bhp', '138.08 bhp', '250 bhp',
#        '74.9 bhp', '91.2 bhp', '102.57 bhp', '97.6 bhp', '102.53 bhp',
#        '240 bhp', '254 bhp', '112.4 bhp', '73.74 bhp', '108.495 bhp',
#        '116.9 bhp', '101 bhp', '320 bhp', '70.02 bhp', '261.49 bhp',
#        '105.5 bhp', '550 bhp', '168.7 bhp', '55.23 bhp', '94.68 bhp',
#        '152.88 bhp', '163.2 bhp', '203.2 bhp', '241 bhp', '95 bhp',
#        '200 bhp', '271.23 bhp', '63.12 bhp', '85.7 bhp', '308.43 bhp',
#        '118.6 bhp', '199.3 bhp', '83.83 bhp', '55 bhp', '83 bhp',
#        '300 bhp', '201 bhp', '262.6 bhp', '163 bhp', '58.33 bhp',
#        '86.76 bhp', '76.9 bhp', '174.57 bhp', '301.73 bhp', '68.1 bhp',
#        '162 bhp', '394.3 bhp', '80.9 bhp', '147.5 bhp', '272 bhp',
#        '340 bhp', '120.33 bhp', '82.4 bhp', '231.1 bhp', '335.3 bhp',
#        '333 bhp', '198.25 bhp', '224.34 bhp', '402 bhp', '261 bhp',
#        '61 bhp', '144 bhp', '71.01 bhp', '271.72 bhp', '134 bhp',
#        '135.1 bhp', '92 bhp', '64.08 bhp', '261.5 bhp', '123.37 bhp',
#        '175.67 bhp', '53 bhp', '110.5 bhp', '178.4 bhp', '193.1 bhp',
#        '41 bhp', '395 bhp', '48.21 bhp', '450 bhp', '421 bhp',
#        '89.75 bhp', '387.3 bhp', '130.3 bhp', '281.61 bhp', '52.8 bhp',
#        '139.01 bhp', '208 bhp', '503 bhp', '168 bhp', '98.82 bhp',
#        '139.07 bhp', '83.11 bhp', '74.93 bhp', '382 bhp', '74.96 bhp',
#        '552 bhp', '127 bhp', '560 bhp', '116.4 bhp', '161.6 bhp',
#        '488.1 bhp', '103 bhp', '181.04 bhp'], dtype=object)

# %%
# Null Values
train['Power'] = train['Power'].fillna('74 bhp')
test['Power'] = test['Power'].fillna('74 bhp')

# %%
power_val = pd.DataFrame(columns=['Power_value'])
power_measure = pd.DataFrame(columns=['Power_measure'])
train = pd.concat([train, power_val, power_measure], axis=1)
test = pd.concat([test, power_val, power_measure], axis=1)

for i in train.index:
    value = train['Power'][i].split()[0]
    measure = train['Power'][i].split()[1]
    train['Power_value'][i] = value
    train['Power_measure'][i] = measure
        
for i in test.index:
    value = test['Power'][i].split()[0]
    measure = test['Power'][i].split()[1]
    test['Power_value'][i] = value
    test['Power_measure'][i] = measure
    
train.drop('Power', axis=1, inplace=True)
test.drop('Power', axis=1, inplace=True)

# %%
train['Power_measure'].value_counts()
# Out:
# bhp    6012
# Name: Power_measure, dtype: int64

# %%
t = train[train['Power_value'] == 'null']
t['Power_value'] = '74'
train[train['Power_value'] == 'null'] = t
t = test[test['Power_value'] == 'null']
t['Power_value'] = '74'
test[test['Power_value'] == 'null'] = t

# %%
train.drop('Power_measure', axis=1, inplace=True)
test.drop('Power_measure', axis=1, inplace=True)

# %% [markdown]
# ## Seats

# %%
train['Seats'][:20]
# Out:
# 0     5.0
# 1     5.0
# 2     5.0
# 3     7.0
# 4     5.0
# 5     5.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9     5.0
# 10    5.0
# 11    5.0
# 12    5.0
# 13    5.0
# 14    5.0
# 15    7.0
# 16    5.0
# 17    5.0
# 18    5.0
# 19    5.0
# Name: Seats, dtype: float64

# %%
train['Seats'].value_counts()
# Out:
# 5.0     5007
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64

# %%
test['Seats'].value_counts()
# Out:
# 5.0     1033
# 7.0      122
# 8.0       36
# 4.0       20
# 6.0        7
# 10.0       3
# 2.0        2
# Name: Seats, dtype: int64

# %%
# Null values
train['Seats'] = train['Seats'].fillna(5.0)
test['Seats'] = test['Seats'].fillna(5.0)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Unnamed: 0

# %%
print(len(train['Unnamed: 0'].value_counts()))
# Out:
# 6012

# %%
plt.figure(figsize=(12, 9))
plt.scatter(train['Unnamed: 0'], train['Price'])

# %% [markdown]
# There is no clear pattern in this feautre, i guess it's gonna be misleading, we gotta drop it.

# %%
print(train.shape, test.shape)
train.drop('Unnamed: 0', axis=1, inplace=True)
test.drop('Unnamed: 0', axis=1, inplace=True)
print(train.shape, test.shape)
# Out:
# (6012, 13) (1234, 12)
# (6012, 12) (1234, 11)

# %% [markdown]
# ## Location

# %%
plt.figure(figsize=(12, 9))
sns.catplot('Location', 'Price', data=train)

# %%
plt.figure(figsize=(12, 9))
sns.barplot('Location', 'Price', data=train)
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Price'>

# %% [markdown]
# ## Year

# %%
plt.figure(figsize=(12, 9))
sns.catplot('Year', 'Price', data=train)

# %%
plt.figure(figsize=(12, 9))
sns.barplot('Year', 'Price', data=train)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Price'>

# %%
plt.figure(figsize=(12, 9))
sns.countplot('Year', data=train)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
plt.figure(figsize=(12, 9))
sns.countplot('Year', data=test)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %% [markdown]
# I guess it would be reasonable to generate a new feature like 'is_after_2014'

# %%
is_after_2014 = pd.DataFrame(columns=['is_after_2014'])
train = pd.concat([train, is_after_2014], axis=1)
test = pd.concat([test, is_after_2014], axis=1)

for i in train.index:
    val = train['Year'][i]
    if val > 2014:
        train['is_after_2014'][i] = 1
    else:
        train['is_after_2014'][i] = 0
        
for i in test.index:
    val = test['Year'][i]
    if val > 2014:
        test['is_after_2014'][i] = 1
    else:
        test['is_after_2014'][i] = 0

# %% [markdown]
# ## Kilometers_Driven

# %%
plt.figure(figsize=(10, 7))
plt.scatter(train['Kilometers_Driven'], train['Price'])

# %% [markdown]
# Generating new feature 'is_kilometers_driven_less_80k' would be useful

# %%
less_80k = pd.DataFrame(columns=['is_kilometers_driven_less_80k'])
train = pd.concat([train, less_80k])
test = pd.concat([test, less_80k])

for i in train.index:
    value = train['Kilometers_Driven'][i]
    if value < 80000:
        train['is_kilometers_driven_less_80k'][i] = 1
    else:
        train['is_kilometers_driven_less_80k'][i] = 0
        
for i in test.index:
    value = test['Kilometers_Driven'][i]
    if value < 80000:
        test['is_kilometers_driven_less_80k'][i] = 1
    else:
        test['is_kilometers_driven_less_80k'][i] = 0

# %% [markdown]
# ## Fuel_Type

# %%
plt.figure(figsize=(10, 7))
sns.catplot('Fuel_Type', 'Price', data=train)

# %%
plt.figure(figsize=(10, 7))
sns.barplot('Fuel_Type', 'Price', data=train)
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Price'>

# %%
test['Fuel_Type'].value_counts()
# Out:
# Diesel    647
# Petrol    579
# CNG         6
# LPG         2
# Name: Fuel_Type, dtype: int64

# %% [markdown]
# - We are gonna generate feature 'is_diesel'
# - Generating features like 'is_electric' is not gonna be useful, cuz there is not electric cars in test set

# %%
is_diesel = pd.DataFrame(columns=['is_diesel'])
train = pd.concat([train, is_diesel], axis=1)
test = pd.concat([test, is_diesel], axis=1)

for i in train.index:
    value = train['Fuel_Type'][i]
    if value == 'Diesel':
        train['is_diesel'][i] = 1
    else:
        train['is_diesel'][i] = 0

for i in test.index:
    value = test['Fuel_Type'][i]
    if value == 'Diesel':
        test['is_diesel'][i] = 1
    else:
        test['is_diesel'][i] = 0

# %% [markdown]
# ## Transmission

# %%
plt.figure(figsize=(10, 7))
sns.catplot('Transmission', 'Price', data=train)

# %%
plt.figure(figsize=(8, 6))
sns.countplot('Transmission', data=train)
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='count'>

# %%
plt.figure(figsize=(10, 7))
sns.barplot('Transmission', 'Price', data=train)
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='Price'>

# %% [markdown]
# Generating 'is_automatic' would be great!

# %%
is_automatic = pd.DataFrame(columns=['is_automatic'])
train = pd.concat([train, is_automatic], axis=1)
test = pd.concat([test, is_automatic], axis=1)

for i in train.index:
    value = train['Transmission'][i]
    if value == 'Automatic':
        train['is_automatic'][i] = 1
    else:
        train['is_automatic'][i] = 0

for i in test.index:
    value = test['Transmission'][i]
    if value == 'Automatic':
        test['is_automatic'][i] = 1
    else:
        test['is_automatic'][i] = 0

# %% [markdown]
# ## Owner_Type

# %%
plt.figure(figsize=(10, 7))
sns.catplot('Owner_Type', 'Price', data=train)

# %%
plt.figure(figsize=(8, 6))
sns.barplot('Owner_Type', 'Price', data=train)
# Out:
# <AxesSubplot:xlabel='Owner_Type', ylabel='Price'>

# %%
plt.figure(figsize=(8, 6))
sns.countplot('Owner_Type', data=train)
# Out:
# <AxesSubplot:xlabel='Owner_Type', ylabel='count'>

# %% [markdown]
# I guess generating feature here is not gonna be that useful

# %% [markdown]
# ## Seats

# %%
print(train['Seats'].value_counts())
print(test['Seats'].value_counts())
# Out:
# 5.0     5049
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64
# 5.0     1044
# 7.0      122
# 8.0       36
# 4.0       20
# 6.0        7
# 10.0       3
# 2.0        2
# Name: Seats, dtype: int64

# %%
print(train.shape)
zero_seat = train[train['Seats'] == 0].index
train.drop(zero_seat, axis=0, inplace=True)
print(train.shape)
# Out:
# (6012, 16)
# (6011, 16)

# %%
plt.figure(figsize=(8, 6))
sns.catplot('Seats', 'Price', data=train)

# %%
plt.figure(figsize=(8, 6))
sns.barplot('Seats', 'Price', data=train)
# Out:
# <AxesSubplot:xlabel='Seats', ylabel='Price'>

# %%
plt.figure(figsize=(8, 6))
sns.countplot('Seats', data=train)
# Out:
# <AxesSubplot:xlabel='Seats', ylabel='count'>

# %% [markdown]
# Generating 'is_2_seats' feature

# %%
is_2_seats = pd.DataFrame(columns=['is_2_seats'])
train = pd.concat([train, is_2_seats], axis=1)
test = pd.concat([test, is_2_seats], axis=1)

for i in train.index:
    value = train['Seats'][i]
    if value == 2:
        train['is_2_seats'][i] = 1
    else:
        train['is_2_seats'][i] = 0
        
for i in test.index:
    value = test['Seats'][i]
    if value == 2:
        test['is_2_seats'][i] = 1
    else:
        test['is_2_seats'][i] = 0

# %% [markdown]
# # Encoding Categorical Features

# %%
for i in ['is_after_2014', 'is_kilometers_driven_less_80k', 
          'is_diesel', 'is_automatic', 'is_2_seats', 
          'Mileage_value', 'Engine_value', 'Power_value']:
    print(i)
    train[i] = train[i].astype('float32')
    test[i] = test[i].astype('float32')
# Out:
# is_after_2014
# is_kilometers_driven_less_80k
# is_diesel
# is_automatic
# is_2_seats
# Mileage_value
# Engine_value
# Power_value

# %%
print(train.shape, test.shape)
cat = train.select_dtypes(include='object')

for i in cat.columns:
    le = LabelEncoder()
    train[i] = le.fit_transform(train[i])
    test[i] = le.transform(test[i])
    
print(train.shape, test.shape)
# Out:
# (6011, 17) (1234, 16)
# (6011, 17) (1234, 16)

# %% [markdown]
# # Normalization

# %%
train_target = train['Price']
train.drop('Price', axis=1, inplace=True)
means = train.mean()
stds = train.std()
train = (train - means) / stds
test = (test- means) / stds

# %%
print(train.shape)
train.head()
# Out:
# (6011, 17)
#    Location      Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0  1.142891 -1.026682           0.440469  -1.570056      0.632035   -0.464009
# 1  1.481244  0.501948          -0.477719  -0.905576      0.632035   -0.464009
# 2 -1.225580 -0.720956          -0.329624   1.087863      0.632035   -0.464009
# 3 -1.225580 -0.415230           0.884753  -0.905576      0.632035   -0.464009
# 4 -0.887227 -0.109504          -0.487493  -0.905576     -1.581928    1.978335
#
#       Seats     Price  Mileage_value  Mileage_measure  Engine_value  \
# 0 -0.345781 -0.691242       1.846843        -9.490035     -1.033562
# 1 -0.345781  0.271071       0.334806         0.105356     -0.060477
# 2 -0.345781 -0.445069       0.014072         0.105356     -0.698647
# 3  2.141936 -0.310793       0.574812         0.105356     -0.617001
# 4 -0.345781  0.740144      -0.640490         0.105356      0.582692
#
#    Power_value  is_after_2014  is_kilometers_driven_less_80k  is_diesel  \
# 0    -1.010905      -0.834834                       0.490270  -1.067219
# 1     0.259433       1.197644                       0.490270   0.936859
# 2    -0.440709      -0.834834                       0.490270  -1.067219
# 3    -0.439589      -0.834834                      -2.039354   0.936859
# 4     0.532022      -0.834834                       0.490270   0.936859
#
#    is_automatic  is_2_seats
# 0     -0.632035   -0.051657
# 1     -0.632035   -0.051657
# 2     -0.632035   -0.051657
# 3     -0.632035   -0.051657
# 4      1.581928   -0.051657

# %%
print(test.shape)
test.head()
# Out:
# (1234, 17)
#    Engine_value  Fuel_Type  Kilometers_Driven  Location  Mileage_measure  \
# 0     -1.033562  -1.570056          -0.479822 -0.548874        -9.490035
# 1     -1.370142   1.087863          -0.078070 -0.887227         0.105356
# 2      1.290845  -0.905576          -0.685051  1.142891         0.105356
# 3     -0.423717  -0.905576           2.424939 -0.210521         0.105356
# 4     -0.701980   1.087863          -0.833146  1.142891         0.105356
#
#    Mileage_value  Owner_Type  Power_value  Price     Seats  Transmission  \
# 0       3.081781   -0.464009    -1.010158    NaN -1.589639      0.632035
# 1       1.432288    1.978335    -1.213666    NaN -0.345781      0.632035
# 2      -0.972134   -0.464009     0.662715    NaN  2.141936      0.632035
# 3       1.190100   -0.464009    -0.715165    NaN -0.345781      0.632035
# 4       0.079528   -0.464009    -0.549931    NaN -0.345781      0.632035
#
#        Year  is_2_seats  is_after_2014  is_automatic  is_diesel  \
# 0  0.196222   -0.051657      -0.834834     -0.632035  -1.067219
# 1 -0.109504   -0.051657      -0.834834     -0.632035  -1.067219
# 2  1.113400   -0.051657       1.197644     -0.632035   0.936859
# 3 -0.415230   -0.051657      -0.834834     -0.632035   0.936859
# 4  0.196222   -0.051657      -0.834834     -0.632035  -1.067219
#
#    is_kilometers_driven_less_80k
# 0                       0.490270
# 1                       0.490270
# 2                       0.490270
# 3                      -2.039354
# 4                       0.490270

# %% [markdown]
# # Modelling

# %%
# Split data
X_train, X_dev, y_train, y_dev = train_test_split(train, train_target, test_size=0.15, random_state=42)
print(X_train.shape)
print(y_train.shape)
print(X_dev.shape)
print(y_dev.shape)
# Out:
# (5109, 16)
# (5109,)
# (902, 16)
# (902,)

# %%
# Linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predict training data
y_pred_lr_train = lr.predict(X_train)

# Evaluation training data
print("MSE on Training Set (Linear Regression):", mean_squared_error(y_pred_lr_train, y_train))

# Predict dev data
y_pred_lr_dev = lr.predict(X_dev)

# Evaluation dev data
print("MSE on Dev Set (Linear Regression):", mean_squared_error(y_pred_lr_dev, y_dev))
# Out:
# MSE on Training Set (Linear Regression): 36.99277969809925
# MSE on Dev Set (Linear Regression): 30.620061775424958

# %%
# Decision Tree
dt = DecisionTreeRegressor(splitter='best', max_depth=5)
dt.fit(X_train, y_train)

# Predict training data
y_pred_dt_train = dt.predict(X_train)

# Evaluation training data
print("MSE on Training Set (Decision Tree):", mean_squared_error(y_pred_dt_train, y_train))

# Predict dev data
y_pred_lr_dev = dt.predict(X_dev)

# Evaluation dev data
print("MSE on Dev Set (Decision Tree):", mean_squared_error(y_pred_lr_dev, y_dev))
# Out:
# MSE on Training Set (Decision Tree): 20.17105705722395
# MSE on Dev Set (Decision Tree): 27.91493508020873

# %%
train.head()
# Out:
#    Location      Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0  1.142891 -1.026682           0.440469  -1.570056      0.632035   -0.464009
# 1  1.481244  0.501948          -0.477719  -0.905576      0.632035   -0.464009
# 2 -1.225580 -0.720956          -0.329624   1.087863      0.632035   -0.464009
# 3 -1.225580 -0.415230           0.884753  -0.905576      0.632035   -0.464009
# 4 -0.887227 -0.109504          -0.487493  -0.905576     -1.581928    1.978335
#
#       Seats  Mileage_value  Mileage_measure  Engine_value  Power_value  \
# 0 -0.345781       1.846843        -9.490035     -1.033562    -1.010905
# 1 -0.345781       0.334806         0.105356     -0.060477     0.259433
# 2 -0.345781       0.014072         0.105356     -0.698647    -0.440709
# 3  2.141936       0.574812         0.105356     -0.617001    -0.439589
# 4 -0.345781      -0.640490         0.105356      0.582692     0.532022
#
#    is_after_2014  is_kilometers_driven_less_80k  is_diesel  is_automatic  \
# 0      -0.834834                       0.490270  -1.067219     -0.632035
# 1       1.197644                       0.490270   0.936859     -0.632035
# 2      -0.834834                       0.490270  -1.067219     -0.632035
# 3      -0.834834                      -2.039354   0.936859     -0.632035
# 4      -0.834834                       0.490270   0.936859      1.581928
#
#    is_2_seats
# 0   -0.051657
# 1   -0.051657
# 2   -0.051657
# 3   -0.051657
# 4   -0.051657

# %%
# Random Froest
rf = RandomForestRegressor(criterion=, n_estimators=20, max_depth=5)
rf.fit(X_train, y_train)

# Predict training data
y_pred_rf_train = rf.predict(X_train)

# Evaluation training data
print("MSE on Training Set (Random Forest):", mean_squared_error(y_pred_rf_train, y_train))

# Predict dev data
y_pred_rf_dev = rf.predict(X_dev)

# Evaluation dev data
print("MSE on Dev Set (Random Forest):", mean_squared_error(y_pred_rf_dev, y_dev))
# Out:
# MSE on Training Set (Random Forest): 16.455674331398832
# MSE on Dev Set (Random Forest): 18.458598049935514

# %%
# Random Forest with Grid Search
rf = RandomForestRegressor(random_state=42)

param_grid = {
    "criterion": ['mse', 'mae'],
    "n_estimators": [5, 10, 15, 20, 25, 30],
    "max_depth": [5, 6, 7, 12, 13, 15]
}

rf_model = GridSearchCV(estimator=rf, cv=5, param_grid=param_grid, verbose=2)
rf_model.fit(train, train_target)
print(rf_model.best_score_)
print(rf_model.best_estimator_.get_params())
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] criterion=mse, max_depth=5, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=5, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=5, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=5, n_estimators=5, total=   0.0s
# [CV] criterion=mse, max_depth=5, n_estimators=5 ......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] ....... criterion=mse, max_depth=5, n_estimators=5, total=   0.0s
# [CV] criterion=mse, max_depth=5, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=5, n_estimators=5, total=   0.0s
# [CV] criterion=mse, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=20, total=   0.2s
# [CV] criterion=mse, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=25, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=25, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=25, total=   0.1s
# [CV] criterion=mse, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=30, total=   0.3s
# [CV] criterion=mse, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=5, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=6, n_estimators=5, total=   0.0s
# [CV] criterion=mse, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=6, n_estimators=5, total=   0.0s
# [CV] criterion=mse, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=6, n_estimators=5, total=   0.0s
# [CV] criterion=mse, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=6, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=6, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=20, total=   0.2s
# [CV] criterion=mse, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=25, total=   0.1s
# [CV] criterion=mse, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=30, total=   0.3s
# [CV] criterion=mse, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=6, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=7, n_estimators=5, total=   0.0s
# [CV] criterion=mse, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=7, n_estimators=5, total=   0.0s
# [CV] criterion=mse, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=7, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=7, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mse, max_depth=7, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=15, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=20, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=20, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=20, total=   0.1s
# [CV] criterion=mse, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=25, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mse, max_depth=7, n_estimators=30, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=12, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=12, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=12, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=12, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=12, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=20, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=20, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=20, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=20, total=   0.2s
# [CV] criterion=mse, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=30, total=   0.5s
# [CV] criterion=mse, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=12, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=13, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=13, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=13, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=13, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=13, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=15, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=20, total=   0.2s
# [CV] criterion=mse, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=30, total=   0.5s
# [CV] criterion=mse, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=30, total=   0.5s
# [CV] criterion=mse, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=13, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=15, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=15, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=15, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=15, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mse, max_depth=15, n_estimators=5, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=10, total=   0.1s
# [CV] criterion=mse, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=15, total=   0.2s
# [CV] criterion=mse, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=20, total=   0.3s
# [CV] criterion=mse, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=25, total=   0.4s
# [CV] criterion=mse, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=25, total=   0.3s
# [CV] criterion=mse, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=30, total=   0.4s
# [CV] criterion=mse, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mse, max_depth=15, n_estimators=30, total=   0.4s
# [CV] criterion=mae, max_depth=5, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=5, n_estimators=5, total=   1.2s
# [CV] criterion=mae, max_depth=5, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=5, n_estimators=5, total=   1.2s
# [CV] criterion=mae, max_depth=5, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=5, n_estimators=5, total=   1.2s
# [CV] criterion=mae, max_depth=5, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=5, n_estimators=5, total=   1.2s
# [CV] criterion=mae, max_depth=5, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=5, n_estimators=5, total=   1.2s
# [CV] criterion=mae, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=10, total=   2.4s
# [CV] criterion=mae, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=10, total=   2.3s
# [CV] criterion=mae, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=10, total=   2.5s
# [CV] criterion=mae, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=10, total=   2.3s
# [CV] criterion=mae, max_depth=5, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=10, total=   2.2s
# [CV] criterion=mae, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=15, total=   3.4s
# [CV] criterion=mae, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=15, total=   3.4s
# [CV] criterion=mae, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=15, total=   3.6s
# [CV] criterion=mae, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=15, total=   3.6s
# [CV] criterion=mae, max_depth=5, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=15, total=   3.6s
# [CV] criterion=mae, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=20, total=   4.8s
# [CV] criterion=mae, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=20, total=   4.8s
# [CV] criterion=mae, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=20, total=   4.7s
# [CV] criterion=mae, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=20, total=   4.8s
# [CV] criterion=mae, max_depth=5, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=20, total=   5.0s
# [CV] criterion=mae, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=25, total=   6.4s
# [CV] criterion=mae, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=25, total=   6.1s
# [CV] criterion=mae, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=25, total=   6.5s
# [CV] criterion=mae, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=25, total=   6.5s
# [CV] criterion=mae, max_depth=5, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=25, total=   6.2s
# [CV] criterion=mae, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=30, total=   7.3s
# [CV] criterion=mae, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=30, total=   7.7s
# [CV] criterion=mae, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=30, total=   7.5s
# [CV] criterion=mae, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=30, total=   7.6s
# [CV] criterion=mae, max_depth=5, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=5, n_estimators=30, total=   7.4s
# [CV] criterion=mae, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=6, n_estimators=5, total=   1.3s
# [CV] criterion=mae, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=6, n_estimators=5, total=   1.3s
# [CV] criterion=mae, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=6, n_estimators=5, total=   1.3s
# [CV] criterion=mae, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=6, n_estimators=5, total=   1.3s
# [CV] criterion=mae, max_depth=6, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=6, n_estimators=5, total=   1.3s
# [CV] criterion=mae, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=10, total=   2.7s
# [CV] criterion=mae, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=10, total=   2.6s
# [CV] criterion=mae, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=10, total=   2.6s
# [CV] criterion=mae, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=10, total=   2.6s
# [CV] criterion=mae, max_depth=6, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=10, total=   2.6s
# [CV] criterion=mae, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=15, total=   3.9s
# [CV] criterion=mae, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=15, total=   3.9s
# [CV] criterion=mae, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=15, total=   3.8s
# [CV] criterion=mae, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=15, total=   3.9s
# [CV] criterion=mae, max_depth=6, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=15, total=   4.3s
# [CV] criterion=mae, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=20, total=   5.3s
# [CV] criterion=mae, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=20, total=   5.1s
# [CV] criterion=mae, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=20, total=   5.0s
# [CV] criterion=mae, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=20, total=   5.0s
# [CV] criterion=mae, max_depth=6, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=20, total=   5.5s
# [CV] criterion=mae, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=25, total=   6.3s
# [CV] criterion=mae, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=25, total=   6.3s
# [CV] criterion=mae, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=25, total=   6.2s
# [CV] criterion=mae, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=25, total=   6.3s
# [CV] criterion=mae, max_depth=6, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=25, total=   6.3s
# [CV] criterion=mae, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=30, total=   8.0s
# [CV] criterion=mae, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=30, total=  10.3s
# [CV] criterion=mae, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=30, total=  11.5s
# [CV] criterion=mae, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=30, total=  10.8s
# [CV] criterion=mae, max_depth=6, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=6, n_estimators=30, total=  11.0s
# [CV] criterion=mae, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=7, n_estimators=5, total=   1.9s
# [CV] criterion=mae, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=7, n_estimators=5, total=   1.8s
# [CV] criterion=mae, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=7, n_estimators=5, total=   1.3s
# [CV] criterion=mae, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=7, n_estimators=5, total=   1.3s
# [CV] criterion=mae, max_depth=7, n_estimators=5 ......................
# [CV] ....... criterion=mae, max_depth=7, n_estimators=5, total=   1.4s
# [CV] criterion=mae, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=10, total=   3.2s
# [CV] criterion=mae, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=10, total=   2.8s
# [CV] criterion=mae, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=10, total=   3.5s
# [CV] criterion=mae, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=10, total=   3.1s
# [CV] criterion=mae, max_depth=7, n_estimators=10 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=10, total=   3.2s
# [CV] criterion=mae, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=15, total=   4.5s
# [CV] criterion=mae, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=15, total=   4.2s
# [CV] criterion=mae, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=15, total=   3.6s
# [CV] criterion=mae, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=15, total=   3.7s
# [CV] criterion=mae, max_depth=7, n_estimators=15 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=15, total=   4.4s
# [CV] criterion=mae, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=20, total=   5.4s
# [CV] criterion=mae, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=20, total=   5.2s
# [CV] criterion=mae, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=20, total=   5.4s
# [CV] criterion=mae, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=20, total=   5.4s
# [CV] criterion=mae, max_depth=7, n_estimators=20 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=20, total=   5.3s
# [CV] criterion=mae, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=25, total=   6.7s
# [CV] criterion=mae, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=25, total=   6.8s
# [CV] criterion=mae, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=25, total=   6.7s
# [CV] criterion=mae, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=25, total=   6.7s
# [CV] criterion=mae, max_depth=7, n_estimators=25 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=25, total=   6.5s
# [CV] criterion=mae, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=30, total=   7.9s
# [CV] criterion=mae, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=30, total=   7.8s
# [CV] criterion=mae, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=30, total=   8.0s
# [CV] criterion=mae, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=30, total=   7.9s
# [CV] criterion=mae, max_depth=7, n_estimators=30 .....................
# [CV] ...... criterion=mae, max_depth=7, n_estimators=30, total=   9.2s
# [CV] criterion=mae, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=12, n_estimators=5, total=   1.9s
# [CV] criterion=mae, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=12, n_estimators=5, total=   1.9s
# [CV] criterion=mae, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=12, n_estimators=5, total=   1.7s
# [CV] criterion=mae, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=12, n_estimators=5, total=   1.6s
# [CV] criterion=mae, max_depth=12, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=12, n_estimators=5, total=   1.7s
# [CV] criterion=mae, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=10, total=   3.1s
# [CV] criterion=mae, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=10, total=   2.9s
# [CV] criterion=mae, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=10, total=   3.0s
# [CV] criterion=mae, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=10, total=   3.2s
# [CV] criterion=mae, max_depth=12, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=10, total=   3.0s
# [CV] criterion=mae, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=15, total=   4.5s
# [CV] criterion=mae, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=15, total=   4.6s
# [CV] criterion=mae, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=15, total=   4.5s
# [CV] criterion=mae, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=15, total=   4.7s
# [CV] criterion=mae, max_depth=12, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=15, total=   4.6s
# [CV] criterion=mae, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=20, total=   6.0s
# [CV] criterion=mae, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=20, total=   6.1s
# [CV] criterion=mae, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=20, total=   6.1s
# [CV] criterion=mae, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=20, total=   6.3s
# [CV] criterion=mae, max_depth=12, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=20, total=   6.1s
# [CV] criterion=mae, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=25, total=   7.7s
# [CV] criterion=mae, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=25, total=   7.5s
# [CV] criterion=mae, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=25, total=   7.4s
# [CV] criterion=mae, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=25, total=   7.7s
# [CV] criterion=mae, max_depth=12, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=25, total=   7.6s
# [CV] criterion=mae, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=30, total=   9.0s
# [CV] criterion=mae, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=30, total=   9.6s
# [CV] criterion=mae, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=30, total=   9.6s
# [CV] criterion=mae, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=30, total=   8.9s
# [CV] criterion=mae, max_depth=12, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=12, n_estimators=30, total=   9.0s
# [CV] criterion=mae, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=13, n_estimators=5, total=   1.6s
# [CV] criterion=mae, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=13, n_estimators=5, total=   1.5s
# [CV] criterion=mae, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=13, n_estimators=5, total=   1.6s
# [CV] criterion=mae, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=13, n_estimators=5, total=   1.6s
# [CV] criterion=mae, max_depth=13, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=13, n_estimators=5, total=   1.5s
# [CV] criterion=mae, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=10, total=   3.1s
# [CV] criterion=mae, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=10, total=   3.1s
# [CV] criterion=mae, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=10, total=   3.0s
# [CV] criterion=mae, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=10, total=   3.1s
# [CV] criterion=mae, max_depth=13, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=10, total=   3.1s
# [CV] criterion=mae, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=15, total=   4.7s
# [CV] criterion=mae, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=15, total=   4.6s
# [CV] criterion=mae, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=15, total=   4.4s
# [CV] criterion=mae, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=15, total=   4.5s
# [CV] criterion=mae, max_depth=13, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=15, total=   4.7s
# [CV] criterion=mae, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=20, total=   6.2s
# [CV] criterion=mae, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=20, total=   5.9s
# [CV] criterion=mae, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=20, total=   5.6s
# [CV] criterion=mae, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=20, total=   5.7s
# [CV] criterion=mae, max_depth=13, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=20, total=   5.7s
# [CV] criterion=mae, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=25, total=   7.3s
# [CV] criterion=mae, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=25, total=   7.2s
# [CV] criterion=mae, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=25, total=   7.5s
# [CV] criterion=mae, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=25, total=   7.1s
# [CV] criterion=mae, max_depth=13, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=25, total=   7.2s
# [CV] criterion=mae, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=30, total=   8.7s
# [CV] criterion=mae, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=30, total=   8.6s
# [CV] criterion=mae, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=30, total=   8.6s
# [CV] criterion=mae, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=30, total=   8.6s
# [CV] criterion=mae, max_depth=13, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=13, n_estimators=30, total=   8.6s
# [CV] criterion=mae, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=15, n_estimators=5, total=   1.5s
# [CV] criterion=mae, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=15, n_estimators=5, total=   1.5s
# [CV] criterion=mae, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=15, n_estimators=5, total=   1.4s
# [CV] criterion=mae, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=15, n_estimators=5, total=   1.5s
# [CV] criterion=mae, max_depth=15, n_estimators=5 .....................
# [CV] ...... criterion=mae, max_depth=15, n_estimators=5, total=   1.5s
# [CV] criterion=mae, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=10, total=   3.0s
# [CV] criterion=mae, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=10, total=   2.9s
# [CV] criterion=mae, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=10, total=   2.9s
# [CV] criterion=mae, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=10, total=   2.9s
# [CV] criterion=mae, max_depth=15, n_estimators=10 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=10, total=   3.0s
# [CV] criterion=mae, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=15, total=   4.5s
# [CV] criterion=mae, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=15, total=   4.3s
# [CV] criterion=mae, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=15, total=   4.3s
# [CV] criterion=mae, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=15, total=   4.4s
# [CV] criterion=mae, max_depth=15, n_estimators=15 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=15, total=   4.3s
# [CV] criterion=mae, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=20, total=   5.9s
# [CV] criterion=mae, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=20, total=   5.9s
# [CV] criterion=mae, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=20, total=   5.7s
# [CV] criterion=mae, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=20, total=   5.8s
# [CV] criterion=mae, max_depth=15, n_estimators=20 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=20, total=   5.9s
# [CV] criterion=mae, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=25, total=   7.4s
# [CV] criterion=mae, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=25, total=   7.6s
# [CV] criterion=mae, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=25, total=   7.1s
# [CV] criterion=mae, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=25, total=   7.3s
# [CV] criterion=mae, max_depth=15, n_estimators=25 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=25, total=   7.2s
# [CV] criterion=mae, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=30, total=   8.9s
# [CV] criterion=mae, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=30, total=   8.7s
# [CV] criterion=mae, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=30, total=   8.6s
# [CV] criterion=mae, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=30, total=   8.5s
# [CV] criterion=mae, max_depth=15, n_estimators=30 ....................
# [CV] ..... criterion=mae, max_depth=15, n_estimators=30, total=   8.8s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed: 15.4min finished
# 0.8678729975950903
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'mse', 'max_depth': 12, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 30, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}

# %%
# TODO: Predict by Random Forest

# %%
# XGBoost
xgbmodel = xgb.XGBRegressor(n_estimators=15, 
                             eta=0.2, gamma=1, max_depth=5, 
                             reg_lambda=1)
xgbmodel.fit(X_train, y_train)

# Predict training data
y_pred_xg_train = xgbmodel.predict(X_train)

# Evaluation training data
print("MSE on Training Set (XGBoost):", mean_squared_error(y_pred_xg_train, y_train))

# Predict dev data
y_pred_xg_dev = xgbmodel.predict(X_dev)

# Evaluation dev data
print("MSE on Dev Set (XGBoost):", mean_squared_error(y_pred_xg_dev, y_dev))
# Out:
# MSE on Training Set (XGBoost): 9.532087107412432
# MSE on Dev Set (XGBoost): 12.609268443847034

# %%
# XGBoost with Grid Search
xgbb = xgb.XGBRegressor()

param_grid_grid_grid = {
    "booster": ['gbtree', 'dart'],
    "eta": [0.01, 0.06, 0.1, 0.7],
    "gamma": [0, 0.5, 1],
    "max_depth": [5, 8, 10, 13, 15],
    "lambda": [0, 1, 2],
    "alpha": [0, 1, 2]
}

xgb_model = GridSearchCV(estimator=xgbb, cv=5, param_grid=param_grid, verbose=2)
xgb_mode.fit(train, train_target)

print(xgb_model.best_score_)
print(xgb_mGridSearchCVSearchCVel.best_estimator_.get_params())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-0afa98d845df> in <module>
#      13 xgb_model = GridSearchCV(estimator=xgbb, cv=5, param_grid=param_grid, verbose=2)
#      14
# ---> 15 print(xgb_model.best_score_)
#      16 print(xgb_model.best_estimator_.get_params())
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_score_'

# %%
# # Neural Network (Pytorch)
# X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
# y_train_tensor = torch.tesnor(y_train, dtype=torch.float32)
# X_dev_tensor = torch.tensor(X_dev, dtype=torch.float32)
# y_dev_tensor = torch.tensor(y_dev, dtype=torch.flaot32)

# # TODO: Build a Neural Network
# class NeuralNetwork(nn.Module):
    
#     def __init__(self, input_dims):
#         super(NeuralNetwork, self).__init__()
#         self.fc1 = nn.Linear()
